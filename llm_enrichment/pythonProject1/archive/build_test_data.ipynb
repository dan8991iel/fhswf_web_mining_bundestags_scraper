# %%
from neo4j import GraphDatabase
import pandas as pd
import json

# Verbindung zur Neo4j-DB
uri = "bolt://localhost:7687"
driver = GraphDatabase.driver(uri, auth=("neo4j", "bundestag_password"))

# %%
# Test: Politiker-Nodes finden
with driver.session() as session:
    result = session.run("MATCH (p:Politician) RETURN p LIMIT 5")
    for record in result:
        print(record["p"])
# Out:
# <Node element_id='4:efc8ecef-1ae9-4ae6-a5c6-3ab222bbb2a5:44' labels=frozenset({'Politician'}) properties={'detail_page': 'https://de.wikipedia.org/wiki/Gerhart_Baum', 'firstname': 'Gerhart', 'full_name': 'Gerhart Baum', 'death_year': '2025', 'birth_year': '1932', 'lastname': 'Baum'}>
# <Node element_id='4:efc8ecef-1ae9-4ae6-a5c6-3ab222bbb2a5:49' labels=frozenset({'Politician'}) properties={'detail_page': 'https://de.wikipedia.org/wiki/Hans_Bardens', 'firstname': 'Hans', 'full_name': 'Hans Bardens', 'death_year': '2003', 'lastname': 'Bardens', 'birth_year': '1927'}>
# <Node element_id='4:efc8ecef-1ae9-4ae6-a5c6-3ab222bbb2a5:55' labels=frozenset({'Politician'}) properties={'detail_page': 'https://de.wikipedia.org/wiki/Willy_Bartsch', 'firstname': 'Willy', 'full_name': 'Willy Bartsch', 'death_year': '1988', 'lastname': 'Bartsch', 'birth_year': '1905'}>
# <Node element_id='4:efc8ecef-1ae9-4ae6-a5c6-3ab222bbb2a5:59' labels=frozenset({'Politician'}) properties={'detail_page': 'https://de.wikipedia.org/wiki/Rainer_Barzel', 'firstname': 'Rainer', 'full_name': 'Rainer Barzel', 'death_year': '2006', 'lastname': 'Barzel', 'birth_year': '1924'}>
# <Node element_id='4:efc8ecef-1ae9-4ae6-a5c6-3ab222bbb2a5:64' labels=frozenset({'Politician'}) properties={'detail_page': 'https://de.wikipedia.org/wiki/Wolfgang_Behrendt_(Politiker)', 'firstname': 'Wolfgang', 'full_name': 'Wolfgang Behrendt', 'birth_year': '1938', 'lastname': 'Behrendt'}>

# %%
# Test: Politiker mit Content-Nodes
with driver.session() as session:
    result = session.run("""
        MATCH (p:Politician)-[:HAS_CONTENT]->(c)
        RETURN p.full_name, c.section_header, c.section_content
        LIMIT 10
    """)
    for record in result:
        print(f"Politiker: {record['p.full_name']}")
        print(f"Header: {record['c.section_header']}")
        print(f"Content: {record['c.section_content'][:100]}...")
        print("-" * 50)
# Out:
# Politiker: Gerhart Baum
# Header: Einzelnachweise
# Content: ↑ Susanne Führer: Gerhart Baum und Burkhard Hirsch. In: deutschlandfunkkultur.de. 21. März 2016, abg...
# --------------------------------------------------
# Politiker: Gerhart Baum
# Header: Weblinks
# Content: Commons: Gerhart Baum – Sammlung von Bildern
# Wikinews: Gerhart Baum – in den Nachrichten
# Wikiquote: ...
# --------------------------------------------------
# Politiker: Gerhart Baum
# Header: Literatur
# Content: Sabine Leutheusser-Schnarrenberger (Hrsg.): In liberaler Mission. Gerhart Baum und die deutsche Demo...
# --------------------------------------------------
# Politiker: Gerhart Baum
# Header: Veröffentlichungen (Auswahl)
# Content: mit Jochen Bölsche (Hrsg.): Der Weg in den Überwachungsstaat. Mit neuen Dokumenten und Stellungnahme...
# --------------------------------------------------
# Politiker: Gerhart Baum
# Header: Filme
# Content: alpha Forum. Gerhart Rudolf Baum. Gespräch, Deutschland, 2009, 43 Min., Moderation: Susanne Zimmer, ...
# --------------------------------------------------
# Politiker: Gerhart Baum
# Header: Kabinette
# Content: Kabinett Brandt II Kabinett Schmidt I Kabinett Schmidt II Kabinett Schmidt III...
# --------------------------------------------------
# Politiker: Gerhart Baum
# Header: Auszeichnungen
# Content: Gerhart Baum, 2023
# Rathaus Köln, Spanischer Bau, Kondolenzbuch, Februar 2025
# Baum erhielt 1980 das G...
# --------------------------------------------------
# Politiker: Gerhart Baum
# Header: Gerhart und Renate Baum-Stiftung
# Content: Gemeinsam mit seiner Frau gründete er die Gerhart und Renate Baum-Stiftung[38], die seit 2016 einen ...
# --------------------------------------------------
# Politiker: Gerhart Baum
# Header: Leben
# Content: Frühe Jahre, Beruf und Privates[Bearbeiten | Quelltext bearbeiten]
# Baum (links) mit dem Parteisprech...
# --------------------------------------------------
# Politiker: Gerhart Baum
# Header: #
# Content: Gerhart Baum (1980) Unterschrift von Gerhart Baum
# Gerhart Rudolf Baum (* 28. Oktober 1932 in Dresden...
# --------------------------------------------------

# %%
# Minister-Daten laden
with open("minister.json", "r") as f:
    ministers = [json.loads(line) for line in f]

print(f"Anzahl Minister: {len(ministers)}")
print(f"Erste Minister: {ministers[0]['Vorname']} {ministers[0]['Nachname']}")
# Out:
# Anzahl Minister: 195
# Erste Minister: Joschka Fischer

# %%
def enrich_ministers_with_content(ministers, driver):
    """Reichert Minister-JSON mit Neo4j Content an"""
    
    enriched_ministers = []
    failed_ministers = []
    
    for i, minister in enumerate(ministers):
        try:
            print(f"Processing {i+1}/{len(ministers)}: {minister['Vorname']} {minister['Nachname']}")
            
            # Politiker UND Content in EINER Query finden
            politician_with_content = find_politician_with_content(
                minister["Vorname"], 
                minister["Nachname"], 
                driver
            )
            
            if politician_with_content:
                # Content-Nodes extrahieren
                content_nodes = politician_with_content["content"]
                
                # Minister-JSON erweitern (nur bei Erfolg!)
                minister["neo4j_content"] = content_nodes
                minister["neo4j_matched"] = True
                minister["neo4j_politician_id"] = politician_with_content["politician"].get("id")
                minister["content_count"] = len(content_nodes)
                
                # NUR erfolgreiche hinzufügen!
                enriched_ministers.append(minister)
                print(f"✅ Matched: {len(content_nodes)} content nodes")
                
            else:
                # Bei keinem Match: NUR in failed_ministers!
                failed_ministers.append(minister)
                print(f"❌ No match found")
                
        except Exception as e:
            print(f"❌ Error processing {minister['Vorname']} {minister['Nachname']}: {str(e)}")
            
            # Bei Fehler: NUR in failed_ministers!
            failed_ministers.append(minister)
    
    return enriched_ministers, failed_ministers

def find_politician_with_content(first_name, last_name, driver):
    """Findet Politiker UND Content in EINER Query"""
    with driver.session() as session:
        # Verschiedene Namensvarianten probieren
        name_variants = [
            (first_name, last_name),
            (first_name.strip(), last_name.strip()),
            (first_name.lower(), last_name.lower()),
            (first_name.title(), last_name.title())
        ]
        
        for fname, lname in name_variants:
            result = session.run("""
                MATCH (p:Politician)-[:HAS_CONTENT]->(c)
                WHERE (p.firstname = $first_name AND p.lastname = $last_name)
                   OR (p.full_name CONTAINS $first_name AND p.full_name CONTAINS $last_name)
                   OR (p.full_name = $full_name)
                RETURN p, collect({
                    section_header: c.section_header,
                    section_content: c.section_content,
                    content_id: c.id
                }) as content
                LIMIT 1
            """, first_name=fname, last_name=lname, full_name=f"{fname} {lname}")
            
            record = result.single()
            if record:
                return {
                    "politician": record["p"],
                    "content": record["content"]
                }
        
        return None

# %%
# Minister laden
with open("minister.json", "r") as f:
    ministers = [json.loads(line) for line in f]

# Mit Content anreichern
enriched_ministers, failed_ministers = enrich_ministers_with_content(ministers, driver)

# Erfolgreiche speichern
with open("minister_with_neo4j_content.json", "w") as f:
    json.dump(enriched_ministers, f, indent=2, ensure_ascii=False)

# Fehlgeschlagene separat speichern
with open("minister_failed_matching.json", "w") as f:
    json.dump(failed_ministers, f, indent=2, ensure_ascii=False)

# Statistiken
matched = sum(1 for m in enriched_ministers if m["neo4j_matched"])
failed = len(failed_ministers)
print(f"✅ Erfolgreich gematched: {matched}/{len(ministers)}")
print(f"❌ Fehlgeschlagen: {failed}")
print(f"📊 Erfolgsrate: {matched/len(ministers)*100:.1f}%")
# Out:
# Processing 1/195: Joschka Fischer
# ✅ Matched: 9 content nodes
# Processing 2/195: Hans Klein
# ✅ Matched: 11 content nodes
# Processing 3/195: Alex Möller
# ✅ Matched: 7 content nodes
# Processing 4/195: Walter  Arendt
# ❌ No match found
# Processing 5/195: Egon  Bahr
# ❌ No match found
# Processing 6/195: Theodor Blank
# ✅ Matched: 6 content nodes
# Processing 7/195: Kurt Bodewig
# ✅ Matched: 10 content nodes
# Processing 8/195: Willy Brandt
# ✅ Matched: 11 content nodes
# Processing 9/195: Aenne Brauksiepe
# ✅ Matched: 10 content nodes
# Processing 10/195: Egon Franke
# ✅ Matched: 13 content nodes
# Processing 11/195: Antje Huber
# ✅ Matched: 5 content nodes
# Processing 12/195: Hans Katzer
# ✅ Matched: 10 content nodes
# Processing 13/195: Georg Leber
# ✅ Matched: 9 content nodes
# Processing 14/195: Paul Lücke
# ✅ Matched: 11 content nodes
# Processing 15/195: Franz Müntefering
# ✅ Matched: 11 content nodes
# Processing 16/195: Karl Ravens
# ✅ Matched: 9 content nodes
# Processing 17/195: Hannelore Rönsch
# ✅ Matched: 10 content nodes
# Processing 18/195: Walter  Scheel
# ✅ Matched: 9 content nodes
# Processing 19/195: Renate Schmidt
# ✅ Matched: 10 content nodes
# Processing 20/195: Kurt Schmücker
# ✅ Matched: 10 content nodes
# Processing 21/195: Käte Strobel
# ✅ Matched: 10 content nodes
# Processing 22/195: Richard Stücklen
# ✅ Matched: 12 content nodes
# Processing 23/195: Kai-Uwe von Hassel
# ✅ Matched: 13 content nodes
# Processing 24/195: Herbert Wehnert
# ❌ No match found
# Processing 25/195: Heinz Westphal
# ✅ Matched: 7 content nodes
# Processing 26/195: Heinrich Windelen
# ✅ Matched: 10 content nodes
# Processing 27/195: Hans-Jürgen Wischnewski
# ✅ Matched: 12 content nodes
# Processing 28/195: Ilse Aigner
# ❌ No match found
# Processing 29/195: Franziska Giffey
# ❌ No match found
# Processing 30/195: Michael Glos
# ✅ Matched: 11 content nodes
# Processing 31/195: Kurt Gscheidle
# ✅ Matched: 9 content nodes
# Processing 32/195: Hubertus Heil
# ✅ Matched: 8 content nodes
# Processing 33/195: Dirk Niebel
# ✅ Matched: 9 content nodes
# Processing 34/195: Walter  Riester
# ✅ Matched: 9 content nodes
# Processing 35/195: Helmut Rohde
# ✅ Matched: 7 content nodes
# Processing 36/195: Werner Schwarz
# ✅ Matched: 8 content nodes
# Processing 37/195: Manuela Schwesig
# ❌ No match found
# Processing 38/195: Peter Altmaier
# ❌ No match found
# Processing 39/195: Daniel Bahr
# ❌ No match found
# Processing 40/195: Gerhart Baum
# ✅ Matched: 10 content nodes
# Processing 41/195: Ernst Benda
# ✅ Matched: 10 content nodes
# Processing 42/195: Friedrich Bohl
# ✅ Matched: 7 content nodes
# Processing 43/195: Jochen Borchert
# ✅ Matched: 7 content nodes
# Processing 44/195: Rainer Brüderle
# ✅ Matched: 8 content nodes
# Processing 45/195: Edelgard Bulmahn
# ✅ Matched: 9 content nodes
# Processing 46/195: Wolfgang  Clement
# ❌ No match found
# Processing 47/195: Herta Däubler-Gmelin
# ✅ Matched: 12 content nodes
# Processing 48/195: Lothar de Maiziere
# ❌ No match found
# Processing 49/195: Alexander Dobrindt
# ✅ Matched: 8 content nodes
# Processing 50/195: Hans  Eichel
# ✅ Matched: 12 content nodes
# Processing 51/195: Hans Arnold Engelhard
# ❌ No match found
# Processing 52/195: Björn Engholm
# ✅ Matched: 13 content nodes
# Processing 53/195: Josef Ertl
# ✅ Matched: 10 content nodes
# Processing 54/195: Andrea Fischer
# ✅ Matched: 6 content nodes
# Processing 55/195: Anke Fuchs
# ✅ Matched: 13 content nodes
# Processing 56/195: Karl-Heinz Funke
# ❌ No match found
# Processing 57/195: Sigmar  Gabriel
# ✅ Matched: 12 content nodes
# Processing 58/195: Hans-Dietrich Genscher
# ✅ Matched: 10 content nodes
# Processing 59/195: Hermann Gröhe
# ✅ Matched: 5 content nodes
# Processing 60/195: Gerda Hasselfeldt
# ✅ Matched: 11 content nodes
# Processing 61/195: Hermann Höcherl
# ✅ Matched: 12 content nodes
# Processing 62/195: Bodo Hombach
# ❌ No match found
# Processing 63/195: Gerhard Jahn
# ✅ Matched: 7 content nodes
# Processing 64/195: Manfred Kanther
# ✅ Matched: 12 content nodes
# Processing 65/195: Anja Karliczek
# ✅ Matched: 7 content nodes
# Processing 66/195: Ignaz Kiechle
# ✅ Matched: 9 content nodes
# Processing 67/195: Kurt Georg Kiesinger
# ✅ Matched: 8 content nodes
# Processing 68/195: Reinhard Klimmt
# ❌ No match found
# Processing 69/195: Julia Klöckner
# ✅ Matched: 9 content nodes
# Processing 70/195: Annegret Kramp-Karrenbauer
# ✅ Matched: 7 content nodes
# Processing 71/195: Renate Künast
# ✅ Matched: 9 content nodes
# Processing 72/195: Oskar Lafontaine
# ✅ Matched: 11 content nodes
# Processing 73/195: Manfred Lahnstein
# ✅ Matched: 9 content nodes
# Processing 74/195: Christine Lambrecht
# ✅ Matched: 10 content nodes
# Processing 75/195: Ernst Lemmer
# ✅ Matched: 10 content nodes
# Processing 76/195: Hans Lenz
# ✅ Matched: 10 content nodes
# Processing 77/195: Sabine  Leutheusse-Schnarrenberger
# ❌ No match found
# Processing 78/195: Heiko Maas
# ✅ Matched: 13 content nodes
# Processing 79/195: Hans Matthöfer
# ✅ Matched: 10 content nodes
# Processing 80/195: Jürgen Möllemann
# ✅ Matched: 13 content nodes
# Processing 81/195: Andrea Nahles
# ✅ Matched: 9 content nodes
# Processing 82/195: Alois Niederalt
# ✅ Matched: 10 content nodes
# Processing 83/195: Claudia  Nolte
# ✅ Matched: 9 content nodes
# Processing 84/195: Rainer Offergeld
# ✅ Matched: 7 content nodes
# Processing 85/195: Eduard Oswald
# ✅ Matched: 9 content nodes
# Processing 86/195: Ronald Pofalla
# ✅ Matched: 5 content nodes
# Processing 87/195: Volker Rühe
# ✅ Matched: 10 content nodes
# Processing 88/195: Rudolf Scharping
# ✅ Matched: 13 content nodes
# Processing 89/195: Otto Schily
# ✅ Matched: 9 content nodes
# Processing 90/195: Marie Schlei
# ✅ Matched: 10 content nodes
# Processing 91/195: Christian Schmidt
# ✅ Matched: 6 content nodes
# Processing 92/195: Ulla Schmidt
# ✅ Matched: 7 content nodes
# Processing 93/195: Helmut Schmidt
# ✅ Matched: 10 content nodes
# Processing 94/195: Olaf Scholz
# ✅ Matched: 15 content nodes
# Processing 95/195: Gerhard Fritz Kurt  Schröder
# ❌ No match found
# Processing 96/195: Svenja Schulze
# ✅ Matched: 6 content nodes
# Processing 97/195: Horst Seehofer
# ✅ Matched: 9 content nodes
# Processing 98/195: Rudolf Seiters
# ✅ Matched: 12 content nodes
# Processing 99/195: Jens Spahn
# ✅ Matched: 12 content nodes
# Processing 100/195: Carl-Dieter Spranger
# ✅ Matched: 9 content nodes
# Processing 101/195: Peer Steinbrücke
# ❌ No match found
# Processing 102/195: Manfred Stolpe
# ❌ No match found
# Processing 103/195: Franz Josef Strauß
# ✅ Matched: 13 content nodes
# Processing 104/195: Wolfgang Tiefensee
# ✅ Matched: 12 content nodes
# Processing 105/195: Jürgen Trittin
# ✅ Matched: 12 content nodes
# Processing 106/195: Heidemarie Wieczorek-Zeul
# ✅ Matched: 10 content nodes
# Processing 107/195: Matthias Wissmann
# ✅ Matched: 13 content nodes
# Processing 108/195: Brigitte Zypries
# ✅ Matched: 10 content nodes
# Processing 109/195: Hans  Apel
# ❌ No match found
# Processing 110/195: Martin Bangemann
# ❌ No match found
# Processing 111/195: Katarina Barley
# ❌ No match found
# Processing 112/195: Rainer Barzel
# ✅ Matched: 12 content nodes
# Processing 113/195: Christine Bergmann
# ❌ No match found
# Processing 114/195: Sabine Bergmann-Pohl
# ✅ Matched: 8 content nodes
# Processing 115/195: Norbert Blüm
# ✅ Matched: 8 content nodes
# Processing 116/195: Wolfgang Bötsch
# ✅ Matched: 10 content nodes
# Processing 117/195: Helge Braun
# ✅ Matched: 10 content nodes
# Processing 118/195: Ewald Bucher
# ✅ Matched: 12 content nodes
# Processing 119/195: Rolf Dahlgrün
# ✅ Matched: 10 content nodes
# Processing 120/195: Thomas de Maiziere
# ❌ No match found
# Processing 121/195: Werner Dollinger
# ✅ Matched: 11 content nodes
# Processing 122/195: Horst Ehmke
# ✅ Matched: 11 content nodes
# Processing 123/195: Herbert Ehrenberg
# ✅ Matched: 8 content nodes
# Processing 124/195: Erhard Eppler
# ✅ Matched: 8 content nodes
# Processing 125/195: Ludwig Erhard
# ✅ Matched: 11 content nodes
# Processing 126/195: Katharina Focke
# ✅ Matched: 11 content nodes
# Processing 127/195: Hans-Peter Friedrich
# ✅ Matched: 6 content nodes
# Processing 128/195: Hans Friedrichs
# ❌ No match found
# Processing 129/195: Heiner Geißler
# ✅ Matched: 12 content nodes
# Processing 130/195: Johann Baptist  Gradl
# ✅ Matched: 11 content nodes
# Processing 131/195: Otto Graf Lambsdorff
# ✅ Matched: 13 content nodes
# Processing 132/195: Dieter Haack
# ✅ Matched: 4 content nodes
# Processing 133/195: Volker Hauff
# ✅ Matched: 9 content nodes
# Processing 134/195: Helmut Haussmann
# ✅ Matched: 10 content nodes
# Processing 135/195: Bruno Heck
# ✅ Matched: 7 content nodes
# Processing 136/195: Gustav Heinemann
# ✅ Matched: 9 content nodes
# Processing 137/195: Barbara  Hendricks
# ✅ Matched: 12 content nodes
# Processing 138/195: Richard Jaeger
# ✅ Matched: 10 content nodes
# Processing 139/195: Franz Josef Jung
# ✅ Matched: 12 content nodes
# Processing 140/195: Klaus Kinkel
# ✅ Matched: 11 content nodes
# Processing 141/195: Helmut Kohl
# ✅ Matched: 10 content nodes
# Processing 142/195: Günther  Krause
# ✅ Matched: 8 content nodes
# Processing 143/195: Heinrich Krone
# ✅ Matched: 8 content nodes
# Processing 144/195: Paul Krüger
# ✅ Matched: 10 content nodes
# Processing 145/195: Karl-Hans Laermann
# ✅ Matched: 10 content nodes
# Processing 146/195: Lauritz Lauritzen
# ✅ Matched: 9 content nodes
# Processing 147/195: Ursula Lehr
# ✅ Matched: 10 content nodes
# Processing 148/195: Hans Leussink
# ❌ No match found
# Processing 149/195: Werner Maihofer
# ✅ Matched: 10 content nodes
# Processing 150/195: Erich Mende
# ✅ Matched: 12 content nodes
# Processing 151/195: Angela  Merkel
# ✅ Matched: 11 content nodes
# Processing 152/195: Gerd Müller
# ✅ Matched: 11 content nodes
# Processing 153/195: Werner Müller
# ✅ Matched: 4 content nodes
# Processing 154/195: Rainer Ortleb
# ✅ Matched: 9 content nodes
# Processing 155/195: Peter Ramsauer
# ✅ Matched: 4 content nodes
# Processing 156/195: Günter Rexrodt
# ✅ Matched: 9 content nodes
# Processing 157/195: Heinz Riesenhuber
# ✅ Matched: 9 content nodes
# Processing 158/195: Philipp Rösler
# ❌ No match found
# Processing 159/195: Norbert Röttgen
# ✅ Matched: 11 content nodes
# Processing 160/195: Jürgen  Rüttgers
# ✅ Matched: 10 content nodes
# Processing 161/195: Wolfgang Schäuble
# ✅ Matched: 9 content nodes
# Processing 162/195: Annette Schavan
# ✅ Matched: 8 content nodes
# Processing 163/195: Andreas Scheuer
# ✅ Matched: 11 content nodes
# Processing 164/195: Karl Schiller
# ✅ Matched: 10 content nodes
# Processing 165/195: Edzard Schmidt-Jortzig
# ✅ Matched: 8 content nodes
# Processing 166/195: Jürgen Schmude
# ✅ Matched: 10 content nodes
# Processing 167/195: Oscar Schneider
# ✅ Matched: 7 content nodes
# Processing 168/195: Rupert Scholz
# ✅ Matched: 10 content nodes
# Processing 169/195: Kristina Schröder
# ❌ No match found
# Processing 170/195: Gerhard Schröder
# ✅ Matched: 19 content nodes
# Processing 171/195: Irmgard  Schwaetzer
# ✅ Matched: 11 content nodes
# Processing 172/195: Elisabeth Schwarzhaupt
# ✅ Matched: 10 content nodes
# Processing 173/195: Christian Schwarz-Schilling
# ✅ Matched: 13 content nodes
# Processing 174/195: Hans-Christoph Seebohm
# ✅ Matched: 11 content nodes
# Processing 175/195: Frank-Walter Steinmeier
# ✅ Matched: 14 content nodes
# Processing 176/195: Gerhard Stoltenberg
# ✅ Matched: 12 content nodes
# Processing 177/195: Peter Struck
# ✅ Matched: 10 content nodes
# Processing 178/195: Rita Süssmuth
# ✅ Matched: 13 content nodes
# Processing 179/195: Klaus Töpfer
# ✅ Matched: 11 content nodes
# Processing 180/195: Hans-Jochen Vogel
# ✅ Matched: 10 content nodes
# Processing 181/195: Andreas von Bülow
# ✅ Matched: 11 content nodes
# Processing 182/195: Ursula von der Leyen
# ✅ Matched: 14 content nodes
# Processing 183/195: Klaus von Dohnanyi
# ✅ Matched: 9 content nodes
# Processing 184/195: Karl-Theodor  von und zu Guttenberg
# ❌ No match found
# Processing 185/195: Theo Waigel
# ✅ Matched: 8 content nodes
# Processing 186/195: Walter  Wallmann
# ✅ Matched: 10 content nodes
# Processing 187/195: Hansjoachim Walther
# ✅ Matched: 9 content nodes
# Processing 188/195: Johanna Wanka
# ❌ No match found
# Processing 189/195: Jürgen Warnke
# ✅ Matched: 10 content nodes
# Processing 190/195: Karl Weber
# ✅ Matched: 5 content nodes
# Processing 191/195: Guido Westerwelle
# ✅ Matched: 8 content nodes
# Processing 192/195: Ludger Westrick
# ❌ No match found
# Processing 193/195: Dorothee Wilms
# ✅ Matched: 10 content nodes
# Processing 194/195: Manfred Wörner
# ✅ Matched: 10 content nodes
# Processing 195/195: Friedrich Zimmermann
# ✅ Matched: 8 content nodes
# ✅ Erfolgreich gematched: 165/195
# ❌ Fehlgeschlagen: 30
# 📊 Erfolgsrate: 84.6%

# %%
# JSON laden
with open("minister_with_neo4j_content.json", "r") as f:
    ministers = json.load(f)

# Anzahl zählen
print(f"Anzahl Minister: {len(ministers)}")
# Out:
# Anzahl Minister: 165

# %%
import json

def filter_education_content(input_file='minister_with_neo4j_content.json', output_file='minister_education_filtered.json'):
    """
    Filtert die JSON-Datei und entfernt die häufigsten Felder, die keine Bildungsinformationen enthalten
    """
    # JSON laden
    with open(input_file, 'r', encoding='utf-8') as f:
        data = json.load(f)
    
    # Felder die gefiltert werden sollen (häufigste, keine Bildungsinfos)
    fields_to_filter = {
        '#',  # Root-Element - 165x
        'Weblinks',  # 163x
        'Einzelnachweise',  # 158x
        'Literatur',  # 114x
        'Abgeordneter',  # 46x
        'Abgeordnete',  # 13x
        'Siehe auch'  # 41x
    }
    
    # Gefilterte Daten erstellen
    filtered_data = []
    total_sections_before = 0
    total_sections_after = 0
    
    for person in data:
        person_copy = person.copy()
        
        # neo4j_content filtern
        if 'neo4j_content' in person_copy:
            original_content = person_copy['neo4j_content']
            total_sections_before += len(original_content)
            
            # Nur Sections behalten, die nicht in der Filter-Liste stehen
            filtered_content = []
            for content in original_content:
                if content.get('section_header') not in fields_to_filter:
                    filtered_content.append(content)
            
            person_copy['neo4j_content'] = filtered_content
            total_sections_after += len(filtered_content)
        
        filtered_data.append(person_copy)
    
    # Gefilterte JSON speichern
    with open(output_file, 'w', encoding='utf-8') as f:
        json.dump(filtered_data, f, ensure_ascii=False, indent=2)
    
    # Statistiken ausgeben
    print(f"=== FILTERUNG ERFOLGREICH ===")
    print(f"Gefilterte JSON gespeichert als: {output_file}")
    print(f"Anzahl Personen: {len(data)}")
    print(f"Gefilterte Felder: {', '.join(fields_to_filter)}")
    print(f"Section-Headers vor Filterung: {total_sections_before}")
    print(f"Section-Headers nach Filterung: {total_sections_after}")
    print(f"Entfernte Sections: {total_sections_before - total_sections_after}")
    print(f"Reduktion: {((total_sections_before - total_sections_after) / total_sections_before * 100):.1f}%")
    
    # Verbleibende Section-Headers analysieren
    remaining_headers = {}
    for person in filtered_data:
        if 'neo4j_content' in person:
            for content in person['neo4j_content']:
                header = content.get('section_header', '')
                remaining_headers[header] = remaining_headers.get(header, 0) + 1
    
    print(f"\n=== VERBLEIBENDE SECTION-HEADERS (Top 20) ===")
    sorted_headers = sorted(remaining_headers.items(), key=lambda x: x[1], reverse=True)
    for header, count in sorted_headers[:20]:
        percentage = (count / len(data)) * 100
        print(f"  {header:<40} | {count:>3}x | {percentage:>5.1f}% der Personen")


filter_education_content()
# Out:
# === FILTERUNG ERFOLGREICH ===
# Gefilterte JSON gespeichert als: minister_education_filtered.json
# Anzahl Personen: 165
# Gefilterte Felder: Einzelnachweise, #, Siehe auch, Weblinks, Abgeordnete, Literatur, Abgeordneter
# Section-Headers vor Filterung: 1612
# Section-Headers nach Filterung: 912
# Entfernte Sections: 700
# Reduktion: 43.4%
#
# === VERBLEIBENDE SECTION-HEADERS (Top 20) ===
#   Öffentliche Ämter                        |  62x |  37.6% der Personen
#   Leben                                    |  58x |  35.2% der Personen
#   Ehrungen                                 |  58x |  35.2% der Personen
#   Partei                                   |  55x |  33.3% der Personen
#   Veröffentlichungen                       |  50x |  30.3% der Personen
#   Kabinette                                |  45x |  27.3% der Personen
#   Leben und Beruf                          |  42x |  25.5% der Personen
#   Auszeichnungen                           |  42x |  25.5% der Personen
#   Ausbildung und Beruf                     |  30x |  18.2% der Personen
#   Familie                                  |  21x |  12.7% der Personen
#   Ehrungen und Auszeichnungen              |  20x |  12.1% der Personen
#   Politische Positionen                    |  20x |  12.1% der Personen
#   Privates                                 |  16x |   9.7% der Personen
#   Politik                                  |  16x |   9.7% der Personen
#   Schriften                                |  13x |   7.9% der Personen
#   Sonstiges                                |  10x |   6.1% der Personen
#   Veröffentlichungen (Auswahl)             |  10x |   6.1% der Personen
#   Politische Laufbahn                      |   9x |   5.5% der Personen
#   Schriften (Auswahl)                      |   9x |   5.5% der Personen
#   Politische Karriere                      |   9x |   5.5% der Personen
